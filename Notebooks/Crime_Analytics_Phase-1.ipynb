# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Kentuckydf = pd.read_csv("../Data/Kentucky_Homicides.csv")

Kentuckydf
# Out:
#                 Series  11-2020  12-2020  01-2021  02-2021  03-2021  04-2021  \
# 0    Kentucky Offenses       28       37       34       18       31       23
# 1  Kentucky Clearances       12       17       22       12       19       11
#
#    05-2021  06-2021  07-2021  ...  02-2025  03-2025  04-2025  05-2025  \
# 0       39       40       31  ...       18       13        6        7
# 1       17       19       13  ...       10        9        7        4
#
#    06-2025  07-2025  08-2025  09-2025  10-2025  11-2025
# 0        6       14        8       11        0      NaN
# 1        4       12        4       12        0      NaN
#
# [2 rows x 62 columns]

# %%
plt.pie(Kentuckydf)

# %%
Indianadf = pd.read_csv("../Data/Indiana_Homicides.csv")

Indianadf
# Out:
#                Series  11-2020  12-2020  01-2021  02-2021  03-2021  04-2021  \
# 0    Indiana Offenses       40       46       36       31       33       35
# 1  Indiana Clearances        7       17       22       18       11       12
#
#    05-2021  06-2021  07-2021  ...  02-2025  03-2025  04-2025  05-2025  \
# 0       36       38       51  ...       12       10       10       10
# 1       14       10       19  ...        7        7        7        4
#
#    06-2025  07-2025  08-2025  09-2025  10-2025  11-2025
# 0       11       12       14        5        0      NaN
# 1        5        3        6        1        0      NaN
#
# [2 rows x 62 columns]

# %%
Illinoisdf = pd.read_csv("../Data/Illinois_Homicides.csv")

Illinoisdf
# Out:
#                 Series  11-2020  12-2020  01-2021  02-2021  03-2021  04-2021  \
# 0    Illinois Offenses       84       84       17       12       13       14
# 1  Illinois Clearances        3        4        7        6        5        8
#
#    05-2021  06-2021  07-2021  ...  02-2025  03-2025  04-2025  05-2025  \
# 0       21       15       95  ...       32       46       36       37
# 1       10        5       11  ...       21       21       21       11
#
#    06-2025  07-2025  08-2025  09-2025  10-2025  11-2025
# 0       44       48       46       47       25        0
# 1       10       21       13       15       11        0
#
# [2 rows x 62 columns]

# %%
Ohiodf = pd.read_csv("../Data/Ohio_Homicides.csv")

Ohiodf
# Out:
#             Series  11-2020  12-2020  01-2021  02-2021  03-2021  04-2021  \
# 0    Ohio Offenses       80       83       72       66       67       68
# 1  Ohio Clearances       26       38       37       29       28       19
#
#    05-2021  06-2021  07-2021  ...  02-2025  03-2025  04-2025  05-2025  \
# 0       85       82      102  ...       29       33       44       38
# 1       29       30       38  ...       21       20       22       15
#
#    06-2025  07-2025  08-2025  09-2025  10-2025  11-2025
# 0       45       43       32       21       24        0
# 1       19       26       16       18       10        1
#
# [2 rows x 62 columns]
